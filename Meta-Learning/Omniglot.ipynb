# %% [markdown]
# # <center> Omniglot Classification </center>
#
# **Omniglot**是元学习中的经典基准数据集，包含1623个不同的字符类别，每个类别有20个样本。本notebook展示了如何使用MAML (Model-Agnostic Meta-Learning)算法在Omniglot数据集上进行Few-Shot学习。

# %%
import time

import pandas as pd
import numpy as np
import matplotlib as mpl
mpl.use('Agg')
import matplotlib.pyplot as plt
plt.style.use('bmh')

import torch
from torch import nn
import torch.nn.functional as F
import torch.optim as optim
torch.manual_seed(1227)
np.random.seed(1227)

import higher

from support.omniglot_loaders import OmniglotNShot

# %% [markdown]
# ## 任务配置参数
#
# 元学习的核心思想是"学会学习"，即训练一个模型使其能够快速适应新任务。在Few-Shot分类任务中：
#
# - **支持集(Support Set)**：用于快速适应的少量标记样本
# - **查询集(Query Set)**：用于评估适应后模型性能的样本
# - **任务(Task)**：由N个类别(N-way)组成，每个类别有K个支持样本(K-shot)和若干查询样本
#
# 定义Few-Shot学习任务的关键参数：
# - `n_way`: 每个任务包含的类别数量（这里设为5类）
# - `k_spt`: 支持集中每个类别的样本数量（5-shot学习）
# - `k_qry`: 查询集中每个类别的样本数量（用于评估）
# - `task_num`: 每个meta-batch中的任务数量（32个任务并行训练）

# %%
class Args:
    def __init__(self):
        self.n_way = 5
        self.k_spt = 3
        self.k_qry = 6
        self.task_num = 4
        self.device = 'cpu'

args = Args()

# %% [markdown]
# ## 数据加载器和神经网络模型构建
#
# ### 任务采样机制
# `OmniglotNShot`数据加载器实现了元学习中的任务采样逻辑：
#
# 1. **任务构建**：从所有可用字符类别中随机选择`n_way`个类别构成一个任务
# 2. **样本采样**：对每个选中的类别，随机采样`k_shot`个样本作为支持集，`k_query`个样本作为查询集
# 3. **批次生成**：同时生成`task_num`个不同的任务构成一个meta-batch
#
# ### 卷积神经网络架构
# 构建一个简单的CNN分类器：
# - 3层卷积层，每层包含BatchNorm和ReLU激活，后接MaxPool
# - 最终通过全连接层输出5个类别的logits
# - 使用Adam优化器进行元参数更新

# %%
# Set up the Omniglot loader.
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

db = OmniglotNShot(
    '/tmp/omniglot-data',
    batchsz=args.task_num,
    n_way=args.n_way,
    k_shot=args.k_spt,
    k_query=args.k_qry,
    imgsz=28,
    device=device,
)

net = nn.Sequential(
    nn.Conv2d(1, 16, 3),
    nn.BatchNorm2d(16, momentum=1, affine=True),
    nn.ReLU(inplace=True),
    nn.MaxPool2d(2, 2),
    nn.Conv2d(16, 16, 3),
    nn.BatchNorm2d(16, momentum=1, affine=True),
    nn.ReLU(inplace=True),
    nn.MaxPool2d(2, 2),
    nn.Conv2d(16, 16, 3),
    nn.BatchNorm2d(16, momentum=1, affine=True),
    nn.ReLU(inplace=True),
    nn.MaxPool2d(2, 2),
    nn.Flatten(),
    nn.Linear(16, 5)).to(device)

# We will use Adam to (meta-)optimize the initial parameters
# to be adapted.
meta_opt = optim.Adam(net.parameters(), lr=1e-3)
# Out:
# load from omniglot.npy.
# DB: train (1200, 20, 1, 28, 28) test (423, 20, 1, 28, 28)

# %% [markdown]
# ## MAML训练函数 - 元学习的核心实现
#
# ### 元学习的双层优化过程
#
# #### 内循环 (Inner Loop) - 任务适应
# 对于每个采样的任务：
# 1. **参数复制**：使用`higher.innerloop_ctx`创建网络参数的可微分副本
# 2. **快速适应**：在支持集上执行`n_inner_iter`次梯度下降步骤
# 3. **参数更新**：`diffopt.step(spt_loss)`更新任务特定的参数
#
# #### 外循环 (Outer Loop) - 元参数优化
# 1. **查询集评估**：使用适应后的参数在查询集上计算损失
# 2. **元梯度计算**：`qry_loss.backward()`计算关于初始参数的梯度
# 3. **元更新**：`meta_opt.step()`更新元参数，使模型更容易适应新任务

# %%
def train(db, net, device, meta_opt, epoch, log):
    net.train()
    n_train_iter = db.x_train.shape[0] // db.batchsz

    for batch_idx in range(n_train_iter):
        start_time = time.time()
        # Sample a batch of support and query images and labels.
        x_spt, y_spt, x_qry, y_qry = db.next()

        task_num, setsz, c_, h, w = x_spt.size()
        querysz = x_qry.size(1)

        # Initialize the inner optimizer to adapt the parameters to
        # the support set.
        n_inner_iter = 3
        inner_opt = torch.optim.SGD(net.parameters(), lr=1e-1)

        qry_losses = []
        qry_accs = []
        meta_opt.zero_grad()
        for i in range(task_num):
            with higher.innerloop_ctx(
                net, inner_opt, copy_initial_weights=False
            ) as (fnet, diffopt):
                # Optimize the likelihood of the support set by taking
                # gradient steps w.r.t. the model's parameters.
                # This adapts the model's meta-parameters to the task.
                # higher is able to automatically keep copies of
                # your network's parameters as they are being updated.
                for _ in range(n_inner_iter):
                    spt_logits = fnet(x_spt[i])
                    spt_loss = F.cross_entropy(spt_logits, y_spt[i])
                    diffopt.step(spt_loss)

                # The final set of adapted parameters will induce some
                # final loss and accuracy on the query dataset.
                # These will be used to update the model's meta-parameters.
                qry_logits = fnet(x_qry[i])
                qry_loss = F.cross_entropy(qry_logits, y_qry[i])
                qry_losses.append(qry_loss.detach())
                qry_acc = (qry_logits.argmax(
                    dim=1) == y_qry[i]).sum().item() / querysz
                qry_accs.append(qry_acc)

                # Update the model's meta-parameters to optimize the query
                # losses across all of the tasks sampled in this batch.
                # This unrolls through the gradient steps.
                qry_loss.backward()

        meta_opt.step()
        qry_losses = sum(qry_losses) / task_num
        qry_accs = 100. * sum(qry_accs) / task_num
        i = epoch + float(batch_idx) / n_train_iter
        iter_time = time.time() - start_time
        if batch_idx % 4 == 0:
            print(
                f'[Epoch {i:.2f}] Train Loss: {qry_losses:.2f} | Acc: {qry_accs:.2f} | Time: {iter_time:.2f}'
            )

        log.append({
            'epoch': i,
            'loss': qry_losses,
            'acc': qry_accs,
            'mode': 'train',
            'time': time.time(),
        })

# %% [markdown]
# ## 测试函数 - 评估元学习的泛化能力
#
# ### 测试流程
# 1. **新任务采样**：从测试集中采样全新的、训练时从未见过的任务
# 2. **快速适应**：使用元训练得到的初始参数，在新任务的支持集上进行少量梯度步骤
# 3. **泛化评估**：在查询集上评估适应后模型的性能
#
# ### 与训练的技术区别
# - **无元梯度追踪**：`track_higher_grads=False`，因为测试时不需要更新元参数
# - **纯前向推理**：`.detach()`操作确保测试过程不影响元参数
# - **真实场景模拟**：每个测试任务都是独立的，模拟实际应用中遇到新任务的情况

# %%
def test(db, net, device, epoch, log):
    # Crucially in our testing procedure here, we do *not* fine-tune
    # the model during testing for simplicity.
    # Most research papers using MAML for this task do an extra
    # stage of fine-tuning here that should be added if you are
    # adapting this code for research.
    net.train()
    n_test_iter = db.x_test.shape[0] // db.batchsz

    qry_losses = []
    qry_accs = []

    for batch_idx in range(n_test_iter):
        x_spt, y_spt, x_qry, y_qry = db.next('test')

        task_num, setsz, c_, h, w = x_spt.size()
        querysz = x_qry.size(1)

        n_inner_iter = 5
        inner_opt = torch.optim.SGD(net.parameters(), lr=1e-1)

        for i in range(task_num):
            with higher.innerloop_ctx(net, inner_opt, track_higher_grads=False) as (fnet, diffopt):
                # Optimize the likelihood of the support set by taking
                # gradient steps w.r.t. the model's parameters.
                # This adapts the model's meta-parameters to the task.
                for _ in range(n_inner_iter):
                    spt_logits = fnet(x_spt[i])
                    spt_loss = F.cross_entropy(spt_logits, y_spt[i])
                    diffopt.step(spt_loss)

                # The query loss and acc induced by these parameters.
                qry_logits = fnet(x_qry[i]).detach()
                qry_loss = F.cross_entropy(
                    qry_logits, y_qry[i], reduction='none')
                qry_losses.append(qry_loss.detach())
                qry_accs.append(
                    (qry_logits.argmax(dim=1) == y_qry[i]).detach())

    qry_losses = torch.cat(qry_losses).mean().item()
    qry_accs = 100. * torch.cat(qry_accs).float().mean().item()
    print(
        f'[Epoch {epoch+1:.2f}] Test Loss: {qry_losses:.2f} | Acc: {qry_accs:.2f}'
    )
    log.append({
        'epoch': epoch + 1,
        'loss': qry_losses,
        'acc': qry_accs,
        'mode': 'test',
        'time': time.time(),
    })

# %% [markdown]
# 可以通过一个简单的可视化函数来直观展示模型训练效果:

# %%
def plot(log):
    df = pd.DataFrame(log)
    fig, ax = plt.subplots(figsize=(6, 4))
    train_df = df[df['mode'] == 'train']
    test_df = df[df['mode'] == 'test']
    ax.plot(train_df['epoch'], train_df['acc'], label='Train')
    ax.plot(test_df['epoch'], test_df['acc'], label='Test')
    ax.set_xlabel('Epoch')
    ax.set_ylabel('Accuracy')
    ax.set_ylim(70, 100)
    fig.legend(ncol=2, loc='lower right')
    fig.tight_layout()
    fname = './figure/maml-accs.png'
    print(f'--- Plotting accuracy to {fname}')
    fig.savefig(fname)
    plt.close(fig)

# %% [markdown]
# ## 执行元学习训练
#
# 以下代码执行完整的MAML训练过程，包含：
#
# 1. **元训练阶段**：
#    - 从训练集中反复采样新任务
#    - 通过双层优化更新元参数
#    - 监控训练过程中的损失和准确率
#
# 2. **元测试阶段**：
#    - 在每个epoch后评估模型的泛化能力
#    - 测试模型在全新任务上的快速适应能力
#
# 3. **结果可视化**

# %%
log = []
for epoch in range(10):
    train(db, net, device, meta_opt, epoch, log)
    test(db, net, device, epoch, log)
    plot(log)
# Out:
# [Epoch 0.00] Train Loss: 0.97 | Acc: 72.50 | Time: 0.11
# [Epoch 0.01] Train Loss: 0.92 | Acc: 77.50 | Time: 0.08
# [Epoch 0.03] Train Loss: 0.99 | Acc: 69.17 | Time: 0.09
# [Epoch 0.04] Train Loss: 1.00 | Acc: 70.00 | Time: 0.08
# [Epoch 0.05] Train Loss: 1.01 | Acc: 75.83 | Time: 0.08
# [Epoch 0.07] Train Loss: 0.97 | Acc: 78.33 | Time: 0.09
# [Epoch 0.08] Train Loss: 0.91 | Acc: 80.00 | Time: 0.10
# [Epoch 0.09] Train Loss: 0.99 | Acc: 69.17 | Time: 0.09
# [Epoch 0.11] Train Loss: 0.93 | Acc: 73.33 | Time: 0.09
# [Epoch 0.12] Train Loss: 0.91 | Acc: 74.17 | Time: 0.08
# [Epoch 0.13] Train Loss: 0.90 | Acc: 77.50 | Time: 0.10
# [Epoch 0.15] Train Loss: 0.66 | Acc: 95.00 | Time: 0.11
# [Epoch 0.16] Train Loss: 0.78 | Acc: 85.83 | Time: 0.13
# [Epoch 0.17] Train Loss: 0.75 | Acc: 88.33 | Time: 0.10
# [Epoch 0.19] Train Loss: 0.73 | Acc: 85.83 | Time: 0.10
# [Epoch 0.20] Train Loss: 0.73 | Acc: 85.83 | Time: 0.11
# [Epoch 0.21] Train Loss: 0.73 | Acc: 84.17 | Time: 0.11
# [Epoch 0.23] Train Loss: 0.72 | Acc: 80.00 | Time: 0.10
# [Epoch 0.24] Train Loss: 0.54 | Acc: 94.17 | Time: 0.10
# [Epoch 0.25] Train Loss: 0.66 | Acc: 85.83 | Time: 0.09
# [Epoch 0.27] Train Loss: 0.63 | Acc: 90.83 | Time: 0.10
# [Epoch 0.28] Train Loss: 0.63 | Acc: 89.17 | Time: 0.09
# [Epoch 0.29] Train Loss: 0.61 | Acc: 86.67 | Time: 0.22
# [Epoch 0.31] Train Loss: 0.73 | Acc: 81.67 | Time: 0.09
# [Epoch 0.32] Train Loss: 0.67 | Acc: 82.50 | Time: 0.13
# [Epoch 0.33] Train Loss: 0.62 | Acc: 83.33 | Time: 0.12
# [Epoch 0.35] Train Loss: 0.72 | Acc: 81.67 | Time: 0.09
# [Epoch 0.36] Train Loss: 0.56 | Acc: 89.17 | Time: 0.08
# [Epoch 0.37] Train Loss: 0.64 | Acc: 89.17 | Time: 0.13
# [Epoch 0.39] Train Loss: 0.46 | Acc: 94.17 | Time: 0.09
# [Epoch 0.40] Train Loss: 0.51 | Acc: 90.00 | Time: 0.09
# [Epoch 0.41] Train Loss: 0.59 | Acc: 88.33 | Time: 0.09
# [Epoch 0.43] Train Loss: 0.51 | Acc: 91.67 | Time: 0.10
# [Epoch 0.44] Train Loss: 0.56 | Acc: 89.17 | Time: 0.10
# [Epoch 0.45] Train Loss: 0.44 | Acc: 96.67 | Time: 0.10
# [Epoch 0.47] Train Loss: 0.49 | Acc: 88.33 | Time: 0.11
# [Epoch 0.48] Train Loss: 0.47 | Acc: 91.67 | Time: 0.10
# [Epoch 0.49] Train Loss: 0.49 | Acc: 93.33 | Time: 0.10
# [Epoch 0.51] Train Loss: 0.48 | Acc: 94.17 | Time: 0.10
# [Epoch 0.52] Train Loss: 0.49 | Acc: 91.67 | Time: 0.10
# [Epoch 0.53] Train Loss: 0.55 | Acc: 85.83 | Time: 0.11
# [Epoch 0.55] Train Loss: 0.40 | Acc: 94.17 | Time: 0.10
# [Epoch 0.56] Train Loss: 0.51 | Acc: 91.67 | Time: 0.10
# [Epoch 0.57] Train Loss: 0.39 | Acc: 91.67 | Time: 0.11
# [Epoch 0.59] Train Loss: 0.39 | Acc: 91.67 | Time: 0.12
# [Epoch 0.60] Train Loss: 0.45 | Acc: 89.17 | Time: 0.11
# [Epoch 0.61] Train Loss: 0.55 | Acc: 85.00 | Time: 0.11
# [Epoch 0.63] Train Loss: 0.40 | Acc: 96.67 | Time: 0.11
# [Epoch 0.64] Train Loss: 0.36 | Acc: 95.00 | Time: 0.10
# [Epoch 0.65] Train Loss: 0.32 | Acc: 95.83 | Time: 0.10
# [Epoch 0.67] Train Loss: 0.42 | Acc: 90.83 | Time: 0.11
# [Epoch 0.68] Train Loss: 0.47 | Acc: 88.33 | Time: 0.10
# [Epoch 0.69] Train Loss: 0.43 | Acc: 89.17 | Time: 0.11
# [Epoch 0.71] Train Loss: 0.37 | Acc: 91.67 | Time: 0.10
# [Epoch 0.72] Train Loss: 0.36 | Acc: 93.33 | Time: 0.12
# [Epoch 0.73] Train Loss: 0.38 | Acc: 94.17 | Time: 0.11
# [Epoch 0.75] Train Loss: 0.47 | Acc: 84.17 | Time: 0.15
# [Epoch 0.76] Train Loss: 0.36 | Acc: 93.33 | Time: 0.10
# [Epoch 0.77] Train Loss: 0.36 | Acc: 95.83 | Time: 0.10
# [Epoch 0.79] Train Loss: 0.32 | Acc: 94.17 | Time: 0.14
# [Epoch 0.80] Train Loss: 0.38 | Acc: 92.50 | Time: 0.13
# [Epoch 0.81] Train Loss: 0.33 | Acc: 95.00 | Time: 0.17
# [Epoch 0.83] Train Loss: 0.36 | Acc: 92.50 | Time: 0.17
# [Epoch 0.84] Train Loss: 0.61 | Acc: 77.50 | Time: 0.15
# [Epoch 0.85] Train Loss: 0.38 | Acc: 93.33 | Time: 0.16
# [Epoch 0.87] Train Loss: 0.34 | Acc: 91.67 | Time: 0.13
# [Epoch 0.88] Train Loss: 0.28 | Acc: 96.67 | Time: 0.17
# [Epoch 0.89] Train Loss: 0.33 | Acc: 90.83 | Time: 0.17
# [Epoch 0.91] Train Loss: 0.35 | Acc: 94.17 | Time: 0.14
# [Epoch 0.92] Train Loss: 0.34 | Acc: 95.00 | Time: 0.11
# [Epoch 0.93] Train Loss: 0.34 | Acc: 93.33 | Time: 0.18
# [Epoch 0.95] Train Loss: 0.31 | Acc: 95.00 | Time: 0.12
# [Epoch 0.96] Train Loss: 0.35 | Acc: 93.33 | Time: 0.22
# [Epoch 0.97] Train Loss: 0.27 | Acc: 94.17 | Time: 0.18
# [Epoch 0.99] Train Loss: 0.36 | Acc: 88.33 | Time: 0.19
# [Epoch 1.00] Test Loss: 0.27 | Acc: 94.44
# --- Plotting accuracy to ./figure/maml-accs.png
# [Epoch 1.00] Train Loss: 0.43 | Acc: 87.50 | Time: 0.14
# [Epoch 1.01] Train Loss: 0.40 | Acc: 90.00 | Time: 0.14
# [Epoch 1.03] Train Loss: 0.27 | Acc: 96.67 | Time: 0.14
# [Epoch 1.04] Train Loss: 0.29 | Acc: 91.67 | Time: 0.15
# [Epoch 1.05] Train Loss: 0.27 | Acc: 93.33 | Time: 0.13
# [Epoch 1.07] Train Loss: 0.23 | Acc: 95.00 | Time: 0.17
# [Epoch 1.08] Train Loss: 0.30 | Acc: 94.17 | Time: 0.15
# [Epoch 1.09] Train Loss: 0.26 | Acc: 95.83 | Time: 0.14
# [Epoch 1.11] Train Loss: 0.30 | Acc: 96.67 | Time: 0.14
# [Epoch 1.12] Train Loss: 0.39 | Acc: 86.67 | Time: 0.14
# [Epoch 1.13] Train Loss: 0.33 | Acc: 91.67 | Time: 0.18
# [Epoch 1.15] Train Loss: 0.28 | Acc: 92.50 | Time: 0.16
# [Epoch 1.16] Train Loss: 0.16 | Acc: 98.33 | Time: 0.17
# [Epoch 1.17] Train Loss: 0.20 | Acc: 96.67 | Time: 0.17
# [Epoch 1.19] Train Loss: 0.25 | Acc: 95.83 | Time: 0.11
# [Epoch 1.20] Train Loss: 0.29 | Acc: 91.67 | Time: 0.12
# [Epoch 1.21] Train Loss: 0.26 | Acc: 95.00 | Time: 0.17
# [Epoch 1.23] Train Loss: 0.29 | Acc: 91.67 | Time: 0.21
# [Epoch 1.24] Train Loss: 0.38 | Acc: 90.83 | Time: 0.16
# [Epoch 1.25] Train Loss: 0.29 | Acc: 95.00 | Time: 0.15
# [Epoch 1.27] Train Loss: 0.38 | Acc: 87.50 | Time: 0.17
# [Epoch 1.28] Train Loss: 0.23 | Acc: 95.83 | Time: 0.14
# [Epoch 1.29] Train Loss: 0.36 | Acc: 90.83 | Time: 0.16
# [Epoch 1.31] Train Loss: 0.31 | Acc: 91.67 | Time: 0.16
# [Epoch 1.32] Train Loss: 0.28 | Acc: 94.17 | Time: 0.20
# [Epoch 1.33] Train Loss: 0.15 | Acc: 97.50 | Time: 0.16
# [Epoch 1.35] Train Loss: 0.22 | Acc: 98.33 | Time: 0.14
# [Epoch 1.36] Train Loss: 0.20 | Acc: 96.67 | Time: 0.16
# [Epoch 1.37] Train Loss: 0.24 | Acc: 90.83 | Time: 0.23
# [Epoch 1.39] Train Loss: 0.22 | Acc: 93.33 | Time: 0.15
# [Epoch 1.40] Train Loss: 0.28 | Acc: 91.67 | Time: 0.19
# [Epoch 1.41] Train Loss: 0.17 | Acc: 98.33 | Time: 0.17
# [Epoch 1.43] Train Loss: 0.32 | Acc: 89.17 | Time: 0.16
# [Epoch 1.44] Train Loss: 0.29 | Acc: 88.33 | Time: 0.14
# [Epoch 1.45] Train Loss: 0.21 | Acc: 96.67 | Time: 0.17
# [Epoch 1.47] Train Loss: 0.25 | Acc: 96.67 | Time: 0.17
# [Epoch 1.48] Train Loss: 0.17 | Acc: 97.50 | Time: 0.16
# [Epoch 1.49] Train Loss: 0.27 | Acc: 92.50 | Time: 0.17
# [Epoch 1.51] Train Loss: 0.29 | Acc: 92.50 | Time: 0.17
# [Epoch 1.52] Train Loss: 0.32 | Acc: 89.17 | Time: 0.15
# [Epoch 1.53] Train Loss: 0.21 | Acc: 93.33 | Time: 0.18
# [Epoch 1.55] Train Loss: 0.27 | Acc: 93.33 | Time: 0.17
# [Epoch 1.56] Train Loss: 0.27 | Acc: 92.50 | Time: 0.15
# [Epoch 1.57] Train Loss: 0.18 | Acc: 96.67 | Time: 0.14
# [Epoch 1.59] Train Loss: 0.27 | Acc: 91.67 | Time: 0.17
# [Epoch 1.60] Train Loss: 0.18 | Acc: 98.33 | Time: 0.16
# [Epoch 1.61] Train Loss: 0.46 | Acc: 87.50 | Time: 0.15
# [Epoch 1.63] Train Loss: 0.22 | Acc: 94.17 | Time: 0.18
# [Epoch 1.64] Train Loss: 0.28 | Acc: 90.83 | Time: 0.15
# [Epoch 1.65] Train Loss: 0.14 | Acc: 97.50 | Time: 0.15
# [Epoch 1.67] Train Loss: 0.35 | Acc: 93.33 | Time: 0.16
# [Epoch 1.68] Train Loss: 0.29 | Acc: 95.00 | Time: 0.18
# [Epoch 1.69] Train Loss: 0.25 | Acc: 91.67 | Time: 0.13
# [Epoch 1.71] Train Loss: 0.33 | Acc: 90.00 | Time: 0.14
# [Epoch 1.72] Train Loss: 0.17 | Acc: 95.83 | Time: 0.18
# [Epoch 1.73] Train Loss: 0.21 | Acc: 95.00 | Time: 0.16
# [Epoch 1.75] Train Loss: 0.24 | Acc: 91.67 | Time: 0.18
# [Epoch 1.76] Train Loss: 0.22 | Acc: 93.33 | Time: 0.17
# [Epoch 1.77] Train Loss: 0.27 | Acc: 91.67 | Time: 0.20
# [Epoch 1.79] Train Loss: 0.23 | Acc: 92.50 | Time: 0.21
# [Epoch 1.80] Train Loss: 0.24 | Acc: 93.33 | Time: 0.18
# [Epoch 1.81] Train Loss: 0.22 | Acc: 90.83 | Time: 0.23
# [Epoch 1.83] Train Loss: 0.28 | Acc: 90.83 | Time: 0.17
# [Epoch 1.84] Train Loss: 0.28 | Acc: 93.33 | Time: 0.25
# [Epoch 1.85] Train Loss: 0.17 | Acc: 96.67 | Time: 0.20
# [Epoch 1.87] Train Loss: 0.17 | Acc: 97.50 | Time: 0.17
# [Epoch 1.88] Train Loss: 0.24 | Acc: 93.33 | Time: 0.18
# [Epoch 1.89] Train Loss: 0.28 | Acc: 90.00 | Time: 0.20
# [Epoch 1.91] Train Loss: 0.17 | Acc: 96.67 | Time: 0.16
# [Epoch 1.92] Train Loss: 0.20 | Acc: 95.83 | Time: 0.18
# [Epoch 1.93] Train Loss: 0.16 | Acc: 96.67 | Time: 0.19
# [Epoch 1.95] Train Loss: 0.19 | Acc: 95.00 | Time: 0.18
# [Epoch 1.96] Train Loss: 0.17 | Acc: 96.67 | Time: 0.17
# [Epoch 1.97] Train Loss: 0.15 | Acc: 97.50 | Time: 0.17
# [Epoch 1.99] Train Loss: 0.11 | Acc: 98.33 | Time: 0.18
# [Epoch 2.00] Test Loss: 0.17 | Acc: 95.56
# --- Plotting accuracy to ./figure/maml-accs.png
# [Epoch 2.00] Train Loss: 0.26 | Acc: 91.67 | Time: 0.16
# [Epoch 2.01] Train Loss: 0.16 | Acc: 95.83 | Time: 0.16
# [Epoch 2.03] Train Loss: 0.15 | Acc: 96.67 | Time: 0.16
# [Epoch 2.04] Train Loss: 0.24 | Acc: 93.33 | Time: 0.14
# [Epoch 2.05] Train Loss: 0.16 | Acc: 96.67 | Time: 0.17
# [Epoch 2.07] Train Loss: 0.22 | Acc: 95.83 | Time: 0.17
# [Epoch 2.08] Train Loss: 0.14 | Acc: 98.33 | Time: 0.14
# [Epoch 2.09] Train Loss: 0.21 | Acc: 94.17 | Time: 0.19
# [Epoch 2.11] Train Loss: 0.23 | Acc: 96.67 | Time: 0.17
# [Epoch 2.12] Train Loss: 0.19 | Acc: 94.17 | Time: 0.12
# [Epoch 2.13] Train Loss: 0.35 | Acc: 82.50 | Time: 0.19
# [Epoch 2.15] Train Loss: 0.19 | Acc: 95.00 | Time: 0.20
# [Epoch 2.16] Train Loss: 0.27 | Acc: 93.33 | Time: 0.16
# [Epoch 2.17] Train Loss: 0.14 | Acc: 97.50 | Time: 0.19
# [Epoch 2.19] Train Loss: 0.16 | Acc: 97.50 | Time: 0.16
# [Epoch 2.20] Train Loss: 0.20 | Acc: 95.00 | Time: 0.17
# [Epoch 2.21] Train Loss: 0.29 | Acc: 91.67 | Time: 0.18
# [Epoch 2.23] Train Loss: 0.27 | Acc: 93.33 | Time: 0.18
# [Epoch 2.24] Train Loss: 0.34 | Acc: 90.00 | Time: 0.16
# [Epoch 2.25] Train Loss: 0.27 | Acc: 94.17 | Time: 0.19
# [Epoch 2.27] Train Loss: 0.19 | Acc: 92.50 | Time: 0.17
# [Epoch 2.28] Train Loss: 0.16 | Acc: 95.00 | Time: 0.19
# [Epoch 2.29] Train Loss: 0.14 | Acc: 96.67 | Time: 0.18
# [Epoch 2.31] Train Loss: 0.20 | Acc: 92.50 | Time: 0.23
# [Epoch 2.32] Train Loss: 0.12 | Acc: 97.50 | Time: 0.19
# [Epoch 2.33] Train Loss: 0.36 | Acc: 84.17 | Time: 0.15
# [Epoch 2.35] Train Loss: 0.12 | Acc: 98.33 | Time: 0.17
# [Epoch 2.36] Train Loss: 0.17 | Acc: 95.83 | Time: 0.17
# [Epoch 2.37] Train Loss: 0.25 | Acc: 90.83 | Time: 0.15
# [Epoch 2.39] Train Loss: 0.19 | Acc: 95.00 | Time: 0.14
# [Epoch 2.40] Train Loss: 0.20 | Acc: 94.17 | Time: 0.15
# [Epoch 2.41] Train Loss: 0.16 | Acc: 98.33 | Time: 0.14
# [Epoch 2.43] Train Loss: 0.15 | Acc: 96.67 | Time: 0.19
# [Epoch 2.44] Train Loss: 0.19 | Acc: 95.00 | Time: 0.16
# [Epoch 2.45] Train Loss: 0.17 | Acc: 94.17 | Time: 0.15
# [Epoch 2.47] Train Loss: 0.12 | Acc: 98.33 | Time: 0.16
# [Epoch 2.48] Train Loss: 0.22 | Acc: 94.17 | Time: 0.14
# [Epoch 2.49] Train Loss: 0.17 | Acc: 95.83 | Time: 0.16
# [Epoch 2.51] Train Loss: 0.16 | Acc: 95.00 | Time: 0.16
# [Epoch 2.52] Train Loss: 0.14 | Acc: 95.83 | Time: 0.09
# [Epoch 2.53] Train Loss: 0.30 | Acc: 91.67 | Time: 0.09
# [Epoch 2.55] Train Loss: 0.15 | Acc: 97.50 | Time: 0.09
# [Epoch 2.56] Train Loss: 0.24 | Acc: 95.83 | Time: 0.09
# [Epoch 2.57] Train Loss: 0.14 | Acc: 95.83 | Time: 0.09
# [Epoch 2.59] Train Loss: 0.20 | Acc: 91.67 | Time: 0.09
# [Epoch 2.60] Train Loss: 0.16 | Acc: 94.17 | Time: 0.11
# [Epoch 2.61] Train Loss: 0.22 | Acc: 95.00 | Time: 0.09
# [Epoch 2.63] Train Loss: 0.15 | Acc: 96.67 | Time: 0.09
# [Epoch 2.64] Train Loss: 0.15 | Acc: 98.33 | Time: 0.09
# [Epoch 2.65] Train Loss: 0.26 | Acc: 93.33 | Time: 0.09
# [Epoch 2.67] Train Loss: 0.17 | Acc: 97.50 | Time: 0.10
# [Epoch 2.68] Train Loss: 0.15 | Acc: 95.83 | Time: 0.09
# [Epoch 2.69] Train Loss: 0.16 | Acc: 97.50 | Time: 0.09
# [Epoch 2.71] Train Loss: 0.16 | Acc: 95.83 | Time: 0.09
# [Epoch 2.72] Train Loss: 0.20 | Acc: 94.17 | Time: 0.09
# [Epoch 2.73] Train Loss: 0.10 | Acc: 98.33 | Time: 0.11
# [Epoch 2.75] Train Loss: 0.15 | Acc: 96.67 | Time: 0.09
# [Epoch 2.76] Train Loss: 0.15 | Acc: 95.00 | Time: 0.09
# [Epoch 2.77] Train Loss: 0.17 | Acc: 94.17 | Time: 0.09
# [Epoch 2.79] Train Loss: 0.22 | Acc: 91.67 | Time: 0.09
# [Epoch 2.80] Train Loss: 0.17 | Acc: 96.67 | Time: 0.15
# [Epoch 2.81] Train Loss: 0.21 | Acc: 93.33 | Time: 0.09
# [Epoch 2.83] Train Loss: 0.17 | Acc: 95.00 | Time: 0.10
# [Epoch 2.84] Train Loss: 0.17 | Acc: 92.50 | Time: 0.09
# [Epoch 2.85] Train Loss: 0.16 | Acc: 96.67 | Time: 0.09
# [Epoch 2.87] Train Loss: 0.19 | Acc: 95.83 | Time: 0.10
# [Epoch 2.88] Train Loss: 0.26 | Acc: 92.50 | Time: 0.09
# [Epoch 2.89] Train Loss: 0.27 | Acc: 92.50 | Time: 0.09
# [Epoch 2.91] Train Loss: 0.11 | Acc: 95.83 | Time: 0.09
# [Epoch 2.92] Train Loss: 0.17 | Acc: 95.00 | Time: 0.09
# [Epoch 2.93] Train Loss: 0.11 | Acc: 98.33 | Time: 0.10
# [Epoch 2.95] Train Loss: 0.23 | Acc: 88.33 | Time: 0.10
# [Epoch 2.96] Train Loss: 0.14 | Acc: 96.67 | Time: 0.09
# [Epoch 2.97] Train Loss: 0.08 | Acc: 99.17 | Time: 0.09
# [Epoch 2.99] Train Loss: 0.19 | Acc: 94.17 | Time: 0.09
# [Epoch 3.00] Test Loss: 0.14 | Acc: 95.79
# --- Plotting accuracy to ./figure/maml-accs.png
# [Epoch 3.00] Train Loss: 0.05 | Acc: 99.17 | Time: 0.10
# [Epoch 3.01] Train Loss: 0.25 | Acc: 94.17 | Time: 0.09
# [Epoch 3.03] Train Loss: 0.20 | Acc: 94.17 | Time: 0.10
# [Epoch 3.04] Train Loss: 0.11 | Acc: 98.33 | Time: 0.09
# [Epoch 3.05] Train Loss: 0.20 | Acc: 93.33 | Time: 0.09
# [Epoch 3.07] Train Loss: 0.12 | Acc: 97.50 | Time: 0.10
# [Epoch 3.08] Train Loss: 0.17 | Acc: 94.17 | Time: 0.09
# [Epoch 3.09] Train Loss: 0.20 | Acc: 91.67 | Time: 0.09
# [Epoch 3.11] Train Loss: 0.13 | Acc: 97.50 | Time: 0.20
# [Epoch 3.12] Train Loss: 0.10 | Acc: 95.00 | Time: 0.09
# [Epoch 3.13] Train Loss: 0.09 | Acc: 98.33 | Time: 0.10
# [Epoch 3.15] Train Loss: 0.18 | Acc: 96.67 | Time: 0.09
# [Epoch 3.16] Train Loss: 0.15 | Acc: 95.00 | Time: 0.10
# [Epoch 3.17] Train Loss: 0.12 | Acc: 95.83 | Time: 0.10
# [Epoch 3.19] Train Loss: 0.13 | Acc: 96.67 | Time: 0.09
# [Epoch 3.20] Train Loss: 0.09 | Acc: 99.17 | Time: 0.10
# [Epoch 3.21] Train Loss: 0.26 | Acc: 90.00 | Time: 0.09
# [Epoch 3.23] Train Loss: 0.19 | Acc: 94.17 | Time: 0.09
# [Epoch 3.24] Train Loss: 0.16 | Acc: 95.83 | Time: 0.09
# [Epoch 3.25] Train Loss: 0.19 | Acc: 95.83 | Time: 0.09
# [Epoch 3.27] Train Loss: 0.19 | Acc: 95.00 | Time: 0.10
# [Epoch 3.28] Train Loss: 0.12 | Acc: 95.83 | Time: 0.10
# [Epoch 3.29] Train Loss: 0.13 | Acc: 94.17 | Time: 0.09
# [Epoch 3.31] Train Loss: 0.16 | Acc: 95.83 | Time: 0.10
# [Epoch 3.32] Train Loss: 0.16 | Acc: 95.00 | Time: 0.10
# [Epoch 3.33] Train Loss: 0.20 | Acc: 95.00 | Time: 0.10
# [Epoch 3.35] Train Loss: 0.12 | Acc: 96.67 | Time: 0.09
# [Epoch 3.36] Train Loss: 0.11 | Acc: 96.67 | Time: 0.10
# [Epoch 3.37] Train Loss: 0.18 | Acc: 94.17 | Time: 0.09
# [Epoch 3.39] Train Loss: 0.17 | Acc: 95.83 | Time: 0.09
# [Epoch 3.40] Train Loss: 0.11 | Acc: 96.67 | Time: 0.10
# [Epoch 3.41] Train Loss: 0.10 | Acc: 98.33 | Time: 0.10
# [Epoch 3.43] Train Loss: 0.11 | Acc: 97.50 | Time: 0.10
# [Epoch 3.44] Train Loss: 0.14 | Acc: 97.50 | Time: 0.10
# [Epoch 3.45] Train Loss: 0.20 | Acc: 94.17 | Time: 0.09
# [Epoch 3.47] Train Loss: 0.10 | Acc: 95.00 | Time: 0.10
# [Epoch 3.48] Train Loss: 0.11 | Acc: 96.67 | Time: 0.10
# [Epoch 3.49] Train Loss: 0.22 | Acc: 91.67 | Time: 0.10
# [Epoch 3.51] Train Loss: 0.13 | Acc: 97.50 | Time: 0.10
# [Epoch 3.52] Train Loss: 0.20 | Acc: 93.33 | Time: 0.10
# [Epoch 3.53] Train Loss: 0.21 | Acc: 92.50 | Time: 0.11
# [Epoch 3.55] Train Loss: 0.10 | Acc: 98.33 | Time: 0.11
# [Epoch 3.56] Train Loss: 0.19 | Acc: 95.83 | Time: 0.09
# [Epoch 3.57] Train Loss: 0.24 | Acc: 92.50 | Time: 0.10
# [Epoch 3.59] Train Loss: 0.11 | Acc: 99.17 | Time: 0.10
# [Epoch 3.60] Train Loss: 0.14 | Acc: 95.83 | Time: 0.10
# [Epoch 3.61] Train Loss: 0.18 | Acc: 95.83 | Time: 0.09
# [Epoch 3.63] Train Loss: 0.18 | Acc: 94.17 | Time: 0.09
# [Epoch 3.64] Train Loss: 0.17 | Acc: 95.00 | Time: 0.10
# [Epoch 3.65] Train Loss: 0.10 | Acc: 98.33 | Time: 0.10
# [Epoch 3.67] Train Loss: 0.12 | Acc: 98.33 | Time: 0.11
# [Epoch 3.68] Train Loss: 0.06 | Acc: 100.00 | Time: 0.12
# [Epoch 3.69] Train Loss: 0.19 | Acc: 96.67 | Time: 0.09
# [Epoch 3.71] Train Loss: 0.13 | Acc: 96.67 | Time: 0.10
# [Epoch 3.72] Train Loss: 0.14 | Acc: 95.00 | Time: 0.10
# [Epoch 3.73] Train Loss: 0.12 | Acc: 97.50 | Time: 0.11
# [Epoch 3.75] Train Loss: 0.13 | Acc: 97.50 | Time: 0.10
# [Epoch 3.76] Train Loss: 0.16 | Acc: 95.83 | Time: 0.10
# [Epoch 3.77] Train Loss: 0.12 | Acc: 95.83 | Time: 0.12
# [Epoch 3.79] Train Loss: 0.12 | Acc: 98.33 | Time: 0.10
# [Epoch 3.80] Train Loss: 0.09 | Acc: 98.33 | Time: 0.11
# [Epoch 3.81] Train Loss: 0.17 | Acc: 95.00 | Time: 0.09
# [Epoch 3.83] Train Loss: 0.14 | Acc: 96.67 | Time: 0.11
# [Epoch 3.84] Train Loss: 0.16 | Acc: 97.50 | Time: 0.10
# [Epoch 3.85] Train Loss: 0.23 | Acc: 92.50 | Time: 0.09
# [Epoch 3.87] Train Loss: 0.12 | Acc: 95.83 | Time: 0.11
# [Epoch 3.88] Train Loss: 0.07 | Acc: 97.50 | Time: 0.10
# [Epoch 3.89] Train Loss: 0.18 | Acc: 95.83 | Time: 0.14
# [Epoch 3.91] Train Loss: 0.08 | Acc: 98.33 | Time: 0.10
# [Epoch 3.92] Train Loss: 0.16 | Acc: 94.17 | Time: 0.10
# [Epoch 3.93] Train Loss: 0.19 | Acc: 93.33 | Time: 0.11
# [Epoch 3.95] Train Loss: 0.15 | Acc: 95.83 | Time: 0.09
# [Epoch 3.96] Train Loss: 0.10 | Acc: 97.50 | Time: 0.10
# [Epoch 3.97] Train Loss: 0.16 | Acc: 94.17 | Time: 0.09
# [Epoch 3.99] Train Loss: 0.16 | Acc: 94.17 | Time: 0.10
# [Epoch 4.00] Test Loss: 0.12 | Acc: 96.19
# --- Plotting accuracy to ./figure/maml-accs.png
# [Epoch 4.00] Train Loss: 0.08 | Acc: 99.17 | Time: 0.10
# [Epoch 4.01] Train Loss: 0.12 | Acc: 95.83 | Time: 0.10
# [Epoch 4.03] Train Loss: 0.15 | Acc: 96.67 | Time: 0.09
# [Epoch 4.04] Train Loss: 0.10 | Acc: 97.50 | Time: 0.09
# [Epoch 4.05] Train Loss: 0.13 | Acc: 96.67 | Time: 0.09
# [Epoch 4.07] Train Loss: 0.09 | Acc: 98.33 | Time: 0.10
# [Epoch 4.08] Train Loss: 0.17 | Acc: 96.67 | Time: 0.10
# [Epoch 4.09] Train Loss: 0.14 | Acc: 95.00 | Time: 0.10
# [Epoch 4.11] Train Loss: 0.14 | Acc: 98.33 | Time: 0.10
# [Epoch 4.12] Train Loss: 0.10 | Acc: 98.33 | Time: 0.10
# [Epoch 4.13] Train Loss: 0.11 | Acc: 96.67 | Time: 0.10
# [Epoch 4.15] Train Loss: 0.11 | Acc: 97.50 | Time: 0.10
# [Epoch 4.16] Train Loss: 0.21 | Acc: 93.33 | Time: 0.16
# [Epoch 4.17] Train Loss: 0.11 | Acc: 96.67 | Time: 0.09
# [Epoch 4.19] Train Loss: 0.23 | Acc: 94.17 | Time: 0.09
# [Epoch 4.20] Train Loss: 0.09 | Acc: 98.33 | Time: 0.10
# [Epoch 4.21] Train Loss: 0.10 | Acc: 98.33 | Time: 0.09
# [Epoch 4.23] Train Loss: 0.19 | Acc: 92.50 | Time: 0.09
# [Epoch 4.24] Train Loss: 0.12 | Acc: 95.00 | Time: 0.09
# [Epoch 4.25] Train Loss: 0.11 | Acc: 96.67 | Time: 0.09
# [Epoch 4.27] Train Loss: 0.14 | Acc: 96.67 | Time: 0.10
# [Epoch 4.28] Train Loss: 0.19 | Acc: 94.17 | Time: 0.09
# [Epoch 4.29] Train Loss: 0.06 | Acc: 98.33 | Time: 0.09
# [Epoch 4.31] Train Loss: 0.17 | Acc: 93.33 | Time: 0.09
# [Epoch 4.32] Train Loss: 0.06 | Acc: 98.33 | Time: 0.09
# [Epoch 4.33] Train Loss: 0.13 | Acc: 96.67 | Time: 0.10
# [Epoch 4.35] Train Loss: 0.18 | Acc: 93.33 | Time: 0.09
# [Epoch 4.36] Train Loss: 0.17 | Acc: 93.33 | Time: 0.09
# [Epoch 4.37] Train Loss: 0.13 | Acc: 95.83 | Time: 0.09
# [Epoch 4.39] Train Loss: 0.14 | Acc: 95.00 | Time: 0.09
# [Epoch 4.40] Train Loss: 0.07 | Acc: 98.33 | Time: 0.10
# [Epoch 4.41] Train Loss: 0.08 | Acc: 97.50 | Time: 0.09
# [Epoch 4.43] Train Loss: 0.10 | Acc: 96.67 | Time: 0.09
# [Epoch 4.44] Train Loss: 0.15 | Acc: 94.17 | Time: 0.10
# [Epoch 4.45] Train Loss: 0.18 | Acc: 93.33 | Time: 0.09
# [Epoch 4.47] Train Loss: 0.10 | Acc: 98.33 | Time: 0.10
# [Epoch 4.48] Train Loss: 0.09 | Acc: 97.50 | Time: 0.09
# [Epoch 4.49] Train Loss: 0.10 | Acc: 97.50 | Time: 0.09
# [Epoch 4.51] Train Loss: 0.17 | Acc: 90.83 | Time: 0.09
# [Epoch 4.52] Train Loss: 0.21 | Acc: 92.50 | Time: 0.09
# [Epoch 4.53] Train Loss: 0.14 | Acc: 95.00 | Time: 0.10
# [Epoch 4.55] Train Loss: 0.17 | Acc: 95.83 | Time: 0.09
# [Epoch 4.56] Train Loss: 0.26 | Acc: 91.67 | Time: 0.09
# [Epoch 4.57] Train Loss: 0.05 | Acc: 99.17 | Time: 0.09
# [Epoch 4.59] Train Loss: 0.20 | Acc: 93.33 | Time: 0.09
# [Epoch 4.60] Train Loss: 0.14 | Acc: 95.00 | Time: 0.10
# [Epoch 4.61] Train Loss: 0.21 | Acc: 92.50 | Time: 0.09
# [Epoch 4.63] Train Loss: 0.12 | Acc: 97.50 | Time: 0.09
# [Epoch 4.64] Train Loss: 0.11 | Acc: 96.67 | Time: 0.09
# [Epoch 4.65] Train Loss: 0.11 | Acc: 95.83 | Time: 0.10
# [Epoch 4.67] Train Loss: 0.14 | Acc: 96.67 | Time: 0.10
# [Epoch 4.68] Train Loss: 0.28 | Acc: 89.17 | Time: 0.09
# [Epoch 4.69] Train Loss: 0.07 | Acc: 98.33 | Time: 0.09
# [Epoch 4.71] Train Loss: 0.06 | Acc: 99.17 | Time: 0.09
# [Epoch 4.72] Train Loss: 0.13 | Acc: 96.67 | Time: 0.09
# [Epoch 4.73] Train Loss: 0.10 | Acc: 96.67 | Time: 0.10
# [Epoch 4.75] Train Loss: 0.10 | Acc: 98.33 | Time: 0.09
# [Epoch 4.76] Train Loss: 0.14 | Acc: 95.83 | Time: 0.09
# [Epoch 4.77] Train Loss: 0.16 | Acc: 95.00 | Time: 0.10
# [Epoch 4.79] Train Loss: 0.18 | Acc: 98.33 | Time: 0.09
# [Epoch 4.80] Train Loss: 0.12 | Acc: 98.33 | Time: 0.09
# [Epoch 4.81] Train Loss: 0.10 | Acc: 97.50 | Time: 0.09
# [Epoch 4.83] Train Loss: 0.17 | Acc: 94.17 | Time: 0.09
# [Epoch 4.84] Train Loss: 0.10 | Acc: 95.00 | Time: 0.09
# [Epoch 4.85] Train Loss: 0.13 | Acc: 96.67 | Time: 0.10
# [Epoch 4.87] Train Loss: 0.09 | Acc: 97.50 | Time: 0.10
# [Epoch 4.88] Train Loss: 0.10 | Acc: 96.67 | Time: 0.09
# [Epoch 4.89] Train Loss: 0.16 | Acc: 95.00 | Time: 0.10
# [Epoch 4.91] Train Loss: 0.18 | Acc: 94.17 | Time: 0.09
# [Epoch 4.92] Train Loss: 0.13 | Acc: 96.67 | Time: 0.09
# [Epoch 4.93] Train Loss: 0.11 | Acc: 96.67 | Time: 0.10
# [Epoch 4.95] Train Loss: 0.13 | Acc: 95.00 | Time: 0.09
# [Epoch 4.96] Train Loss: 0.19 | Acc: 93.33 | Time: 0.09
# [Epoch 4.97] Train Loss: 0.11 | Acc: 98.33 | Time: 0.09
# [Epoch 4.99] Train Loss: 0.13 | Acc: 96.67 | Time: 0.09
# [Epoch 5.00] Test Loss: 0.11 | Acc: 96.70
# --- Plotting accuracy to ./figure/maml-accs.png
# [Epoch 5.00] Train Loss: 0.16 | Acc: 93.33 | Time: 0.10
# [Epoch 5.01] Train Loss: 0.15 | Acc: 95.00 | Time: 0.09
# [Epoch 5.03] Train Loss: 0.13 | Acc: 96.67 | Time: 0.09
# [Epoch 5.04] Train Loss: 0.20 | Acc: 93.33 | Time: 0.09
# [Epoch 5.05] Train Loss: 0.11 | Acc: 96.67 | Time: 0.09
# [Epoch 5.07] Train Loss: 0.07 | Acc: 98.33 | Time: 0.09
# [Epoch 5.08] Train Loss: 0.19 | Acc: 94.17 | Time: 0.09
# [Epoch 5.09] Train Loss: 0.18 | Acc: 93.33 | Time: 0.09
# [Epoch 5.11] Train Loss: 0.12 | Acc: 97.50 | Time: 0.09
# [Epoch 5.12] Train Loss: 0.10 | Acc: 98.33 | Time: 0.09
# [Epoch 5.13] Train Loss: 0.19 | Acc: 95.00 | Time: 0.10
# [Epoch 5.15] Train Loss: 0.11 | Acc: 95.83 | Time: 0.09
# [Epoch 5.16] Train Loss: 0.20 | Acc: 90.83 | Time: 0.09
# [Epoch 5.17] Train Loss: 0.10 | Acc: 98.33 | Time: 0.10
# [Epoch 5.19] Train Loss: 0.10 | Acc: 97.50 | Time: 0.09
# [Epoch 5.20] Train Loss: 0.18 | Acc: 95.00 | Time: 0.10
# [Epoch 5.21] Train Loss: 0.13 | Acc: 95.83 | Time: 0.16
# [Epoch 5.23] Train Loss: 0.24 | Acc: 91.67 | Time: 0.09
# [Epoch 5.24] Train Loss: 0.22 | Acc: 91.67 | Time: 0.10
# [Epoch 5.25] Train Loss: 0.07 | Acc: 99.17 | Time: 0.10
# [Epoch 5.27] Train Loss: 0.11 | Acc: 97.50 | Time: 0.10
# [Epoch 5.28] Train Loss: 0.10 | Acc: 97.50 | Time: 0.09
# [Epoch 5.29] Train Loss: 0.09 | Acc: 99.17 | Time: 0.09
# [Epoch 5.31] Train Loss: 0.18 | Acc: 94.17 | Time: 0.09
# [Epoch 5.32] Train Loss: 0.22 | Acc: 94.17 | Time: 0.09
# [Epoch 5.33] Train Loss: 0.12 | Acc: 96.67 | Time: 0.10
# [Epoch 5.35] Train Loss: 0.12 | Acc: 96.67 | Time: 0.10
# [Epoch 5.36] Train Loss: 0.05 | Acc: 100.00 | Time: 0.14
# [Epoch 5.37] Train Loss: 0.07 | Acc: 98.33 | Time: 0.09
# [Epoch 5.39] Train Loss: 0.09 | Acc: 98.33 | Time: 0.09
# [Epoch 5.40] Train Loss: 0.12 | Acc: 95.83 | Time: 0.10
# [Epoch 5.41] Train Loss: 0.12 | Acc: 95.83 | Time: 0.09
# [Epoch 5.43] Train Loss: 0.14 | Acc: 93.33 | Time: 0.09
# [Epoch 5.44] Train Loss: 0.11 | Acc: 98.33 | Time: 0.10
# [Epoch 5.45] Train Loss: 0.13 | Acc: 96.67 | Time: 0.09
# [Epoch 5.47] Train Loss: 0.09 | Acc: 96.67 | Time: 0.10
# [Epoch 5.48] Train Loss: 0.13 | Acc: 95.00 | Time: 0.10
# [Epoch 5.49] Train Loss: 0.11 | Acc: 97.50 | Time: 0.09
# [Epoch 5.51] Train Loss: 0.10 | Acc: 95.83 | Time: 0.09
# [Epoch 5.52] Train Loss: 0.19 | Acc: 95.00 | Time: 0.09
# [Epoch 5.53] Train Loss: 0.17 | Acc: 94.17 | Time: 0.11
# [Epoch 5.55] Train Loss: 0.23 | Acc: 91.67 | Time: 0.10
# [Epoch 5.56] Train Loss: 0.05 | Acc: 100.00 | Time: 0.09
# [Epoch 5.57] Train Loss: 0.23 | Acc: 90.83 | Time: 0.10
# [Epoch 5.59] Train Loss: 0.10 | Acc: 96.67 | Time: 0.10
# [Epoch 5.60] Train Loss: 0.17 | Acc: 95.00 | Time: 0.10
# [Epoch 5.61] Train Loss: 0.06 | Acc: 99.17 | Time: 0.10
# [Epoch 5.63] Train Loss: 0.08 | Acc: 98.33 | Time: 0.09
# [Epoch 5.64] Train Loss: 0.09 | Acc: 97.50 | Time: 0.10
# [Epoch 5.65] Train Loss: 0.06 | Acc: 99.17 | Time: 0.10
# [Epoch 5.67] Train Loss: 0.06 | Acc: 98.33 | Time: 0.10
# [Epoch 5.68] Train Loss: 0.18 | Acc: 94.17 | Time: 0.09
# [Epoch 5.69] Train Loss: 0.07 | Acc: 98.33 | Time: 0.09
# [Epoch 5.71] Train Loss: 0.09 | Acc: 97.50 | Time: 0.09
# [Epoch 5.72] Train Loss: 0.07 | Acc: 97.50 | Time: 0.09
# [Epoch 5.73] Train Loss: 0.22 | Acc: 92.50 | Time: 0.10
# [Epoch 5.75] Train Loss: 0.21 | Acc: 95.00 | Time: 0.09
# [Epoch 5.76] Train Loss: 0.14 | Acc: 95.00 | Time: 0.09
# [Epoch 5.77] Train Loss: 0.05 | Acc: 98.33 | Time: 0.09
# [Epoch 5.79] Train Loss: 0.12 | Acc: 95.00 | Time: 0.09
# [Epoch 5.80] Train Loss: 0.16 | Acc: 95.83 | Time: 0.10
# [Epoch 5.81] Train Loss: 0.14 | Acc: 95.83 | Time: 0.09
# [Epoch 5.83] Train Loss: 0.19 | Acc: 93.33 | Time: 0.10
# [Epoch 5.84] Train Loss: 0.09 | Acc: 96.67 | Time: 0.10
# [Epoch 5.85] Train Loss: 0.07 | Acc: 97.50 | Time: 0.10
# [Epoch 5.87] Train Loss: 0.12 | Acc: 97.50 | Time: 0.10
# [Epoch 5.88] Train Loss: 0.05 | Acc: 98.33 | Time: 0.09
# [Epoch 5.89] Train Loss: 0.12 | Acc: 95.00 | Time: 0.09
# [Epoch 5.91] Train Loss: 0.10 | Acc: 95.83 | Time: 0.09
# [Epoch 5.92] Train Loss: 0.09 | Acc: 99.17 | Time: 0.09
# [Epoch 5.93] Train Loss: 0.20 | Acc: 91.67 | Time: 0.10
# [Epoch 5.95] Train Loss: 0.10 | Acc: 95.00 | Time: 0.10
# [Epoch 5.96] Train Loss: 0.06 | Acc: 97.50 | Time: 0.10
# [Epoch 5.97] Train Loss: 0.08 | Acc: 98.33 | Time: 0.10
# [Epoch 5.99] Train Loss: 0.06 | Acc: 98.33 | Time: 0.11
# [Epoch 6.00] Test Loss: 0.11 | Acc: 96.56
# --- Plotting accuracy to ./figure/maml-accs.png
# [Epoch 6.00] Train Loss: 0.10 | Acc: 97.50 | Time: 0.10
# [Epoch 6.01] Train Loss: 0.25 | Acc: 90.00 | Time: 0.09
# [Epoch 6.03] Train Loss: 0.13 | Acc: 98.33 | Time: 0.09
# [Epoch 6.04] Train Loss: 0.12 | Acc: 96.67 | Time: 0.09
# [Epoch 6.05] Train Loss: 0.12 | Acc: 95.83 | Time: 0.09
# [Epoch 6.07] Train Loss: 0.22 | Acc: 91.67 | Time: 0.10
# [Epoch 6.08] Train Loss: 0.21 | Acc: 94.17 | Time: 0.09
# [Epoch 6.09] Train Loss: 0.13 | Acc: 94.17 | Time: 0.09
# [Epoch 6.11] Train Loss: 0.04 | Acc: 99.17 | Time: 0.09
# [Epoch 6.12] Train Loss: 0.08 | Acc: 96.67 | Time: 0.09
# [Epoch 6.13] Train Loss: 0.20 | Acc: 93.33 | Time: 0.10
# [Epoch 6.15] Train Loss: 0.16 | Acc: 94.17 | Time: 0.10
# [Epoch 6.16] Train Loss: 0.08 | Acc: 98.33 | Time: 0.10
# [Epoch 6.17] Train Loss: 0.09 | Acc: 97.50 | Time: 0.10
# [Epoch 6.19] Train Loss: 0.08 | Acc: 99.17 | Time: 0.12
# [Epoch 6.20] Train Loss: 0.09 | Acc: 99.17 | Time: 0.10
# [Epoch 6.21] Train Loss: 0.07 | Acc: 98.33 | Time: 0.17
# [Epoch 6.23] Train Loss: 0.23 | Acc: 92.50 | Time: 0.10
# [Epoch 6.24] Train Loss: 0.16 | Acc: 96.67 | Time: 0.10
# [Epoch 6.25] Train Loss: 0.12 | Acc: 95.83 | Time: 0.10
# [Epoch 6.27] Train Loss: 0.19 | Acc: 93.33 | Time: 0.10
# [Epoch 6.28] Train Loss: 0.11 | Acc: 94.17 | Time: 0.10
# [Epoch 6.29] Train Loss: 0.11 | Acc: 95.00 | Time: 0.09
# [Epoch 6.31] Train Loss: 0.09 | Acc: 97.50 | Time: 0.10
# [Epoch 6.32] Train Loss: 0.13 | Acc: 96.67 | Time: 0.09
# [Epoch 6.33] Train Loss: 0.17 | Acc: 97.50 | Time: 0.10
# [Epoch 6.35] Train Loss: 0.24 | Acc: 93.33 | Time: 0.09
# [Epoch 6.36] Train Loss: 0.05 | Acc: 99.17 | Time: 0.09
# [Epoch 6.37] Train Loss: 0.11 | Acc: 96.67 | Time: 0.09
# [Epoch 6.39] Train Loss: 0.13 | Acc: 96.67 | Time: 0.09
# [Epoch 6.40] Train Loss: 0.17 | Acc: 90.83 | Time: 0.11
# [Epoch 6.41] Train Loss: 0.09 | Acc: 95.00 | Time: 0.10
# [Epoch 6.43] Train Loss: 0.27 | Acc: 91.67 | Time: 0.10
# [Epoch 6.44] Train Loss: 0.18 | Acc: 95.83 | Time: 0.10
# [Epoch 6.45] Train Loss: 0.12 | Acc: 96.67 | Time: 0.10
# [Epoch 6.47] Train Loss: 0.18 | Acc: 92.50 | Time: 0.10
# [Epoch 6.48] Train Loss: 0.19 | Acc: 94.17 | Time: 0.10
# [Epoch 6.49] Train Loss: 0.18 | Acc: 94.17 | Time: 0.11
# [Epoch 6.51] Train Loss: 0.14 | Acc: 94.17 | Time: 0.09
# [Epoch 6.52] Train Loss: 0.16 | Acc: 92.50 | Time: 0.10
# [Epoch 6.53] Train Loss: 0.13 | Acc: 96.67 | Time: 0.10
# [Epoch 6.55] Train Loss: 0.07 | Acc: 98.33 | Time: 0.10
# [Epoch 6.56] Train Loss: 0.09 | Acc: 97.50 | Time: 0.10
# [Epoch 6.57] Train Loss: 0.07 | Acc: 97.50 | Time: 0.10
# [Epoch 6.59] Train Loss: 0.08 | Acc: 98.33 | Time: 0.09
# [Epoch 6.60] Train Loss: 0.10 | Acc: 96.67 | Time: 0.10
# [Epoch 6.61] Train Loss: 0.18 | Acc: 94.17 | Time: 0.10
# [Epoch 6.63] Train Loss: 0.08 | Acc: 97.50 | Time: 0.11
# [Epoch 6.64] Train Loss: 0.12 | Acc: 95.83 | Time: 0.10
# [Epoch 6.65] Train Loss: 0.23 | Acc: 91.67 | Time: 0.10
# [Epoch 6.67] Train Loss: 0.09 | Acc: 98.33 | Time: 0.10
# [Epoch 6.68] Train Loss: 0.08 | Acc: 96.67 | Time: 0.09
# [Epoch 6.69] Train Loss: 0.13 | Acc: 95.00 | Time: 0.09
# [Epoch 6.71] Train Loss: 0.12 | Acc: 96.67 | Time: 0.09
# [Epoch 6.72] Train Loss: 0.07 | Acc: 97.50 | Time: 0.10
# [Epoch 6.73] Train Loss: 0.12 | Acc: 95.00 | Time: 0.10
# [Epoch 6.75] Train Loss: 0.11 | Acc: 95.83 | Time: 0.09
# [Epoch 6.76] Train Loss: 0.12 | Acc: 95.83 | Time: 0.10
# [Epoch 6.77] Train Loss: 0.10 | Acc: 98.33 | Time: 0.09
# [Epoch 6.79] Train Loss: 0.08 | Acc: 95.83 | Time: 0.10
# [Epoch 6.80] Train Loss: 0.07 | Acc: 98.33 | Time: 0.10
# [Epoch 6.81] Train Loss: 0.18 | Acc: 93.33 | Time: 0.10
# [Epoch 6.83] Train Loss: 0.02 | Acc: 100.00 | Time: 0.09
# [Epoch 6.84] Train Loss: 0.05 | Acc: 98.33 | Time: 0.09
# [Epoch 6.85] Train Loss: 0.13 | Acc: 95.83 | Time: 0.09
# [Epoch 6.87] Train Loss: 0.10 | Acc: 96.67 | Time: 0.10
# [Epoch 6.88] Train Loss: 0.11 | Acc: 96.67 | Time: 0.10
# [Epoch 6.89] Train Loss: 0.11 | Acc: 95.83 | Time: 0.09
# [Epoch 6.91] Train Loss: 0.14 | Acc: 95.00 | Time: 0.10
# [Epoch 6.92] Train Loss: 0.23 | Acc: 90.00 | Time: 0.09
# [Epoch 6.93] Train Loss: 0.15 | Acc: 96.67 | Time: 0.10
# [Epoch 6.95] Train Loss: 0.05 | Acc: 99.17 | Time: 0.10
# [Epoch 6.96] Train Loss: 0.09 | Acc: 97.50 | Time: 0.10
# [Epoch 6.97] Train Loss: 0.26 | Acc: 90.83 | Time: 0.10
# [Epoch 6.99] Train Loss: 0.05 | Acc: 98.33 | Time: 0.09
# [Epoch 7.00] Test Loss: 0.11 | Acc: 96.71
# --- Plotting accuracy to ./figure/maml-accs.png
# [Epoch 7.00] Train Loss: 0.06 | Acc: 99.17 | Time: 0.10
# [Epoch 7.01] Train Loss: 0.06 | Acc: 98.33 | Time: 0.10
# [Epoch 7.03] Train Loss: 0.09 | Acc: 99.17 | Time: 0.10
# [Epoch 7.04] Train Loss: 0.11 | Acc: 96.67 | Time: 0.10
# [Epoch 7.05] Train Loss: 0.09 | Acc: 99.17 | Time: 0.09
# [Epoch 7.07] Train Loss: 0.07 | Acc: 97.50 | Time: 0.10
# [Epoch 7.08] Train Loss: 0.10 | Acc: 98.33 | Time: 0.09
# [Epoch 7.09] Train Loss: 0.07 | Acc: 99.17 | Time: 0.09
# [Epoch 7.11] Train Loss: 0.18 | Acc: 95.00 | Time: 0.09
# [Epoch 7.12] Train Loss: 0.14 | Acc: 92.50 | Time: 0.09
# [Epoch 7.13] Train Loss: 0.09 | Acc: 95.83 | Time: 0.10
# [Epoch 7.15] Train Loss: 0.13 | Acc: 94.17 | Time: 0.10
# [Epoch 7.16] Train Loss: 0.08 | Acc: 96.67 | Time: 0.10
# [Epoch 7.17] Train Loss: 0.06 | Acc: 98.33 | Time: 0.11
# [Epoch 7.19] Train Loss: 0.05 | Acc: 99.17 | Time: 0.10
# [Epoch 7.20] Train Loss: 0.14 | Acc: 92.50 | Time: 0.10
# [Epoch 7.21] Train Loss: 0.08 | Acc: 97.50 | Time: 0.10
# [Epoch 7.23] Train Loss: 0.08 | Acc: 98.33 | Time: 0.10
# [Epoch 7.24] Train Loss: 0.08 | Acc: 98.33 | Time: 0.10
# [Epoch 7.25] Train Loss: 0.20 | Acc: 92.50 | Time: 0.11
# [Epoch 7.27] Train Loss: 0.13 | Acc: 95.00 | Time: 0.10
# [Epoch 7.28] Train Loss: 0.06 | Acc: 99.17 | Time: 0.10
# [Epoch 7.29] Train Loss: 0.08 | Acc: 97.50 | Time: 0.09
# [Epoch 7.31] Train Loss: 0.08 | Acc: 98.33 | Time: 0.11
# [Epoch 7.32] Train Loss: 0.13 | Acc: 97.50 | Time: 0.13
# [Epoch 7.33] Train Loss: 0.11 | Acc: 95.83 | Time: 0.14
# [Epoch 7.35] Train Loss: 0.08 | Acc: 96.67 | Time: 0.10
# [Epoch 7.36] Train Loss: 0.08 | Acc: 98.33 | Time: 0.11
# [Epoch 7.37] Train Loss: 0.08 | Acc: 98.33 | Time: 0.12
# [Epoch 7.39] Train Loss: 0.08 | Acc: 97.50 | Time: 0.10
# [Epoch 7.40] Train Loss: 0.23 | Acc: 91.67 | Time: 0.10
# [Epoch 7.41] Train Loss: 0.15 | Acc: 93.33 | Time: 0.09
# [Epoch 7.43] Train Loss: 0.09 | Acc: 96.67 | Time: 0.09
# [Epoch 7.44] Train Loss: 0.17 | Acc: 94.17 | Time: 0.08
# [Epoch 7.45] Train Loss: 0.12 | Acc: 97.50 | Time: 0.08
# [Epoch 7.47] Train Loss: 0.05 | Acc: 99.17 | Time: 0.09
# [Epoch 7.48] Train Loss: 0.22 | Acc: 94.17 | Time: 0.08
# [Epoch 7.49] Train Loss: 0.07 | Acc: 99.17 | Time: 0.08
# [Epoch 7.51] Train Loss: 0.13 | Acc: 93.33 | Time: 0.08
# [Epoch 7.52] Train Loss: 0.11 | Acc: 95.83 | Time: 0.08
# [Epoch 7.53] Train Loss: 0.11 | Acc: 95.83 | Time: 0.09
# [Epoch 7.55] Train Loss: 0.13 | Acc: 95.00 | Time: 0.08
# [Epoch 7.56] Train Loss: 0.07 | Acc: 98.33 | Time: 0.08
# [Epoch 7.57] Train Loss: 0.10 | Acc: 96.67 | Time: 0.08
# [Epoch 7.59] Train Loss: 0.21 | Acc: 93.33 | Time: 0.08
# [Epoch 7.60] Train Loss: 0.10 | Acc: 95.83 | Time: 0.09
# [Epoch 7.61] Train Loss: 0.08 | Acc: 97.50 | Time: 0.08
# [Epoch 7.63] Train Loss: 0.10 | Acc: 95.00 | Time: 0.08
# [Epoch 7.64] Train Loss: 0.05 | Acc: 98.33 | Time: 0.08
# [Epoch 7.65] Train Loss: 0.14 | Acc: 95.83 | Time: 0.08
# [Epoch 7.67] Train Loss: 0.10 | Acc: 95.83 | Time: 0.09
# [Epoch 7.68] Train Loss: 0.10 | Acc: 95.83 | Time: 0.08
# [Epoch 7.69] Train Loss: 0.14 | Acc: 95.00 | Time: 0.08
# [Epoch 7.71] Train Loss: 0.15 | Acc: 95.83 | Time: 0.08
# [Epoch 7.72] Train Loss: 0.12 | Acc: 94.17 | Time: 0.08
# [Epoch 7.73] Train Loss: 0.10 | Acc: 95.83 | Time: 0.09
# [Epoch 7.75] Train Loss: 0.11 | Acc: 95.00 | Time: 0.08
# [Epoch 7.76] Train Loss: 0.13 | Acc: 97.50 | Time: 0.08
# [Epoch 7.77] Train Loss: 0.06 | Acc: 97.50 | Time: 0.08
# [Epoch 7.79] Train Loss: 0.07 | Acc: 98.33 | Time: 0.08
# [Epoch 7.80] Train Loss: 0.10 | Acc: 96.67 | Time: 0.08
# [Epoch 7.81] Train Loss: 0.11 | Acc: 96.67 | Time: 0.08
# [Epoch 7.83] Train Loss: 0.07 | Acc: 97.50 | Time: 0.08
# [Epoch 7.84] Train Loss: 0.09 | Acc: 95.00 | Time: 0.08
# [Epoch 7.85] Train Loss: 0.11 | Acc: 93.33 | Time: 0.08
# [Epoch 7.87] Train Loss: 0.07 | Acc: 96.67 | Time: 0.09
# [Epoch 7.88] Train Loss: 0.09 | Acc: 97.50 | Time: 0.08
# [Epoch 7.89] Train Loss: 0.11 | Acc: 95.00 | Time: 0.08
# [Epoch 7.91] Train Loss: 0.12 | Acc: 96.67 | Time: 0.08
# [Epoch 7.92] Train Loss: 0.15 | Acc: 95.83 | Time: 0.08
# [Epoch 7.93] Train Loss: 0.09 | Acc: 98.33 | Time: 0.09
# [Epoch 7.95] Train Loss: 0.10 | Acc: 98.33 | Time: 0.08
# [Epoch 7.96] Train Loss: 0.06 | Acc: 100.00 | Time: 0.08
# [Epoch 7.97] Train Loss: 0.08 | Acc: 97.50 | Time: 0.08
# [Epoch 7.99] Train Loss: 0.14 | Acc: 95.83 | Time: 0.08
# [Epoch 8.00] Test Loss: 0.09 | Acc: 97.01
# --- Plotting accuracy to ./figure/maml-accs.png
# [Epoch 8.00] Train Loss: 0.11 | Acc: 97.50 | Time: 0.09
# [Epoch 8.01] Train Loss: 0.06 | Acc: 97.50 | Time: 0.08
# [Epoch 8.03] Train Loss: 0.08 | Acc: 99.17 | Time: 0.08
# [Epoch 8.04] Train Loss: 0.09 | Acc: 97.50 | Time: 0.08
# [Epoch 8.05] Train Loss: 0.06 | Acc: 98.33 | Time: 0.08
# [Epoch 8.07] Train Loss: 0.09 | Acc: 97.50 | Time: 0.08
# [Epoch 8.08] Train Loss: 0.15 | Acc: 95.00 | Time: 0.08
# [Epoch 8.09] Train Loss: 0.19 | Acc: 94.17 | Time: 0.08
# [Epoch 8.11] Train Loss: 0.11 | Acc: 96.67 | Time: 0.08
# [Epoch 8.12] Train Loss: 0.10 | Acc: 95.83 | Time: 0.08
# [Epoch 8.13] Train Loss: 0.12 | Acc: 97.50 | Time: 0.08
# [Epoch 8.15] Train Loss: 0.14 | Acc: 95.00 | Time: 0.08
# [Epoch 8.16] Train Loss: 0.08 | Acc: 96.67 | Time: 0.08
# [Epoch 8.17] Train Loss: 0.15 | Acc: 95.83 | Time: 0.08
# [Epoch 8.19] Train Loss: 0.09 | Acc: 97.50 | Time: 0.08
# [Epoch 8.20] Train Loss: 0.06 | Acc: 97.50 | Time: 0.08
# [Epoch 8.21] Train Loss: 0.11 | Acc: 97.50 | Time: 0.08
# [Epoch 8.23] Train Loss: 0.14 | Acc: 96.67 | Time: 0.08
# [Epoch 8.24] Train Loss: 0.09 | Acc: 98.33 | Time: 0.08
# [Epoch 8.25] Train Loss: 0.12 | Acc: 95.83 | Time: 0.09
# [Epoch 8.27] Train Loss: 0.07 | Acc: 99.17 | Time: 0.09
# [Epoch 8.28] Train Loss: 0.05 | Acc: 99.17 | Time: 0.08
# [Epoch 8.29] Train Loss: 0.12 | Acc: 96.67 | Time: 0.08
# [Epoch 8.31] Train Loss: 0.05 | Acc: 98.33 | Time: 0.08
# [Epoch 8.32] Train Loss: 0.15 | Acc: 93.33 | Time: 0.08
# [Epoch 8.33] Train Loss: 0.09 | Acc: 96.67 | Time: 0.09
# [Epoch 8.35] Train Loss: 0.18 | Acc: 94.17 | Time: 0.08
# [Epoch 8.36] Train Loss: 0.04 | Acc: 99.17 | Time: 0.08
# [Epoch 8.37] Train Loss: 0.08 | Acc: 97.50 | Time: 0.08
# [Epoch 8.39] Train Loss: 0.17 | Acc: 95.00 | Time: 0.08
# [Epoch 8.40] Train Loss: 0.06 | Acc: 99.17 | Time: 0.08
# [Epoch 8.41] Train Loss: 0.14 | Acc: 95.00 | Time: 0.08
# [Epoch 8.43] Train Loss: 0.06 | Acc: 99.17 | Time: 0.08
# [Epoch 8.44] Train Loss: 0.12 | Acc: 95.00 | Time: 0.08
# [Epoch 8.45] Train Loss: 0.10 | Acc: 98.33 | Time: 0.08
# [Epoch 8.47] Train Loss: 0.14 | Acc: 95.00 | Time: 0.08
# [Epoch 8.48] Train Loss: 0.14 | Acc: 95.83 | Time: 0.08
# [Epoch 8.49] Train Loss: 0.08 | Acc: 98.33 | Time: 0.08
# [Epoch 8.51] Train Loss: 0.08 | Acc: 97.50 | Time: 0.08
# [Epoch 8.52] Train Loss: 0.11 | Acc: 95.83 | Time: 0.08
# [Epoch 8.53] Train Loss: 0.15 | Acc: 95.00 | Time: 0.08
# [Epoch 8.55] Train Loss: 0.16 | Acc: 95.83 | Time: 0.08
# [Epoch 8.56] Train Loss: 0.17 | Acc: 92.50 | Time: 0.08
# [Epoch 8.57] Train Loss: 0.12 | Acc: 96.67 | Time: 0.08
# [Epoch 8.59] Train Loss: 0.09 | Acc: 97.50 | Time: 0.08
# [Epoch 8.60] Train Loss: 0.08 | Acc: 97.50 | Time: 0.08
# [Epoch 8.61] Train Loss: 0.21 | Acc: 94.17 | Time: 0.08
# [Epoch 8.63] Train Loss: 0.06 | Acc: 99.17 | Time: 0.08
# [Epoch 8.64] Train Loss: 0.09 | Acc: 96.67 | Time: 0.08
# [Epoch 8.65] Train Loss: 0.15 | Acc: 93.33 | Time: 0.08
# [Epoch 8.67] Train Loss: 0.03 | Acc: 99.17 | Time: 0.09
# [Epoch 8.68] Train Loss: 0.11 | Acc: 97.50 | Time: 0.09
# [Epoch 8.69] Train Loss: 0.04 | Acc: 99.17 | Time: 0.08
# [Epoch 8.71] Train Loss: 0.13 | Acc: 94.17 | Time: 0.09
# [Epoch 8.72] Train Loss: 0.12 | Acc: 97.50 | Time: 0.08
# [Epoch 8.73] Train Loss: 0.08 | Acc: 99.17 | Time: 0.09
# [Epoch 8.75] Train Loss: 0.09 | Acc: 97.50 | Time: 0.10
# [Epoch 8.76] Train Loss: 0.17 | Acc: 91.67 | Time: 0.08
# [Epoch 8.77] Train Loss: 0.11 | Acc: 96.67 | Time: 0.08
# [Epoch 8.79] Train Loss: 0.05 | Acc: 99.17 | Time: 0.08
# [Epoch 8.80] Train Loss: 0.12 | Acc: 97.50 | Time: 0.08
# [Epoch 8.81] Train Loss: 0.09 | Acc: 97.50 | Time: 0.08
# [Epoch 8.83] Train Loss: 0.08 | Acc: 98.33 | Time: 0.08
# [Epoch 8.84] Train Loss: 0.12 | Acc: 96.67 | Time: 0.08
# [Epoch 8.85] Train Loss: 0.07 | Acc: 97.50 | Time: 0.08
# [Epoch 8.87] Train Loss: 0.07 | Acc: 97.50 | Time: 0.09
# [Epoch 8.88] Train Loss: 0.07 | Acc: 98.33 | Time: 0.08
# [Epoch 8.89] Train Loss: 0.14 | Acc: 96.67 | Time: 0.08
# [Epoch 8.91] Train Loss: 0.08 | Acc: 98.33 | Time: 0.09
# [Epoch 8.92] Train Loss: 0.14 | Acc: 95.83 | Time: 0.08
# [Epoch 8.93] Train Loss: 0.14 | Acc: 94.17 | Time: 0.08
# [Epoch 8.95] Train Loss: 0.06 | Acc: 97.50 | Time: 0.08
# [Epoch 8.96] Train Loss: 0.14 | Acc: 95.83 | Time: 0.11
# [Epoch 8.97] Train Loss: 0.07 | Acc: 97.50 | Time: 0.08
# [Epoch 8.99] Train Loss: 0.14 | Acc: 93.33 | Time: 0.08
# [Epoch 9.00] Test Loss: 0.09 | Acc: 97.16
# --- Plotting accuracy to ./figure/maml-accs.png
# [Epoch 9.00] Train Loss: 0.17 | Acc: 95.83 | Time: 0.09
# [Epoch 9.01] Train Loss: 0.10 | Acc: 95.00 | Time: 0.08
# [Epoch 9.03] Train Loss: 0.10 | Acc: 98.33 | Time: 0.08
# [Epoch 9.04] Train Loss: 0.15 | Acc: 93.33 | Time: 0.08
# [Epoch 9.05] Train Loss: 0.08 | Acc: 95.83 | Time: 0.08
# [Epoch 9.07] Train Loss: 0.05 | Acc: 99.17 | Time: 0.08
# [Epoch 9.08] Train Loss: 0.13 | Acc: 96.67 | Time: 0.08
# [Epoch 9.09] Train Loss: 0.14 | Acc: 95.83 | Time: 0.08
# [Epoch 9.11] Train Loss: 0.14 | Acc: 95.83 | Time: 0.08
# [Epoch 9.12] Train Loss: 0.16 | Acc: 94.17 | Time: 0.08
# [Epoch 9.13] Train Loss: 0.07 | Acc: 97.50 | Time: 0.09
# [Epoch 9.15] Train Loss: 0.10 | Acc: 97.50 | Time: 0.08
# [Epoch 9.16] Train Loss: 0.13 | Acc: 95.00 | Time: 0.08
# [Epoch 9.17] Train Loss: 0.08 | Acc: 96.67 | Time: 0.08
# [Epoch 9.19] Train Loss: 0.07 | Acc: 98.33 | Time: 0.08
# [Epoch 9.20] Train Loss: 0.17 | Acc: 94.17 | Time: 0.09
# [Epoch 9.21] Train Loss: 0.05 | Acc: 98.33 | Time: 0.10
# [Epoch 9.23] Train Loss: 0.03 | Acc: 100.00 | Time: 0.08
# [Epoch 9.24] Train Loss: 0.09 | Acc: 98.33 | Time: 0.08
# [Epoch 9.25] Train Loss: 0.04 | Acc: 99.17 | Time: 0.08
# [Epoch 9.27] Train Loss: 0.10 | Acc: 96.67 | Time: 0.09
# [Epoch 9.28] Train Loss: 0.13 | Acc: 95.83 | Time: 0.08
# [Epoch 9.29] Train Loss: 0.10 | Acc: 97.50 | Time: 0.09
# [Epoch 9.31] Train Loss: 0.20 | Acc: 92.50 | Time: 0.08
# [Epoch 9.32] Train Loss: 0.09 | Acc: 95.83 | Time: 0.08
# [Epoch 9.33] Train Loss: 0.08 | Acc: 98.33 | Time: 0.09
# [Epoch 9.35] Train Loss: 0.07 | Acc: 97.50 | Time: 0.08
# [Epoch 9.36] Train Loss: 0.06 | Acc: 98.33 | Time: 0.08
# [Epoch 9.37] Train Loss: 0.04 | Acc: 98.33 | Time: 0.08
# [Epoch 9.39] Train Loss: 0.12 | Acc: 96.67 | Time: 0.08
# [Epoch 9.40] Train Loss: 0.09 | Acc: 95.83 | Time: 0.08
# [Epoch 9.41] Train Loss: 0.14 | Acc: 96.67 | Time: 0.08
# [Epoch 9.43] Train Loss: 0.23 | Acc: 91.67 | Time: 0.08
# [Epoch 9.44] Train Loss: 0.15 | Acc: 95.83 | Time: 0.08
# [Epoch 9.45] Train Loss: 0.09 | Acc: 97.50 | Time: 0.10
# [Epoch 9.47] Train Loss: 0.03 | Acc: 99.17 | Time: 0.10
# [Epoch 9.48] Train Loss: 0.10 | Acc: 96.67 | Time: 0.09
# [Epoch 9.49] Train Loss: 0.10 | Acc: 96.67 | Time: 0.11
# [Epoch 9.51] Train Loss: 0.18 | Acc: 94.17 | Time: 0.09
# [Epoch 9.52] Train Loss: 0.12 | Acc: 95.00 | Time: 0.08
# [Epoch 9.53] Train Loss: 0.04 | Acc: 99.17 | Time: 0.18
# [Epoch 9.55] Train Loss: 0.06 | Acc: 99.17 | Time: 0.08
# [Epoch 9.56] Train Loss: 0.10 | Acc: 97.50 | Time: 0.08
# [Epoch 9.57] Train Loss: 0.10 | Acc: 95.83 | Time: 0.08
# [Epoch 9.59] Train Loss: 0.05 | Acc: 98.33 | Time: 0.08
# [Epoch 9.60] Train Loss: 0.16 | Acc: 93.33 | Time: 0.08
# [Epoch 9.61] Train Loss: 0.18 | Acc: 97.50 | Time: 0.08
# [Epoch 9.63] Train Loss: 0.05 | Acc: 98.33 | Time: 0.08
# [Epoch 9.64] Train Loss: 0.21 | Acc: 90.83 | Time: 0.08
# [Epoch 9.65] Train Loss: 0.08 | Acc: 95.83 | Time: 0.08
# [Epoch 9.67] Train Loss: 0.09 | Acc: 95.83 | Time: 0.09
# [Epoch 9.68] Train Loss: 0.05 | Acc: 100.00 | Time: 0.08
# [Epoch 9.69] Train Loss: 0.12 | Acc: 95.83 | Time: 0.08
# [Epoch 9.71] Train Loss: 0.05 | Acc: 99.17 | Time: 0.08
# [Epoch 9.72] Train Loss: 0.06 | Acc: 99.17 | Time: 0.08
# [Epoch 9.73] Train Loss: 0.10 | Acc: 96.67 | Time: 0.08
# [Epoch 9.75] Train Loss: 0.07 | Acc: 97.50 | Time: 0.08
# [Epoch 9.76] Train Loss: 0.04 | Acc: 99.17 | Time: 0.08
# [Epoch 9.77] Train Loss: 0.11 | Acc: 96.67 | Time: 0.08
# [Epoch 9.79] Train Loss: 0.06 | Acc: 98.33 | Time: 0.08
# [Epoch 9.80] Train Loss: 0.10 | Acc: 96.67 | Time: 0.08
# [Epoch 9.81] Train Loss: 0.08 | Acc: 98.33 | Time: 0.08
# [Epoch 9.83] Train Loss: 0.09 | Acc: 96.67 | Time: 0.08
# [Epoch 9.84] Train Loss: 0.13 | Acc: 95.00 | Time: 0.08
# [Epoch 9.85] Train Loss: 0.14 | Acc: 95.00 | Time: 0.08
# [Epoch 9.87] Train Loss: 0.04 | Acc: 99.17 | Time: 0.08
# [Epoch 9.88] Train Loss: 0.11 | Acc: 98.33 | Time: 0.08
# [Epoch 9.89] Train Loss: 0.16 | Acc: 93.33 | Time: 0.08
# [Epoch 9.91] Train Loss: 0.10 | Acc: 96.67 | Time: 0.08
# [Epoch 9.92] Train Loss: 0.15 | Acc: 95.83 | Time: 0.08
# [Epoch 9.93] Train Loss: 0.04 | Acc: 99.17 | Time: 0.08
# [Epoch 9.95] Train Loss: 0.20 | Acc: 92.50 | Time: 0.08
# [Epoch 9.96] Train Loss: 0.15 | Acc: 94.17 | Time: 0.08
# [Epoch 9.97] Train Loss: 0.12 | Acc: 95.83 | Time: 0.08
# [Epoch 9.99] Train Loss: 0.13 | Acc: 95.83 | Time: 0.08
# [Epoch 10.00] Test Loss: 0.09 | Acc: 96.88
# --- Plotting accuracy to ./figure/maml-accs.png
